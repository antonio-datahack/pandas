# %% [markdown]
# <a id='section0'></a>
# ### Table of Contents
#
# 1. [The `pd.concat()` Method, Part 1](#section1)
# 2. [The `pd.concat()` Method, Part 2](#section2)
# 3. [The `.append()` Method](#section3)
# 4. [Inner Joins, Part 1](#section4)
# 5. [Inner Joins, Part 2](#section5)
# 6. [Outer Joins](#section6)
# 7. [Left Joins](#section7)
# 8. [The `left_on` and `right_on` Parameters](#section8)
# 9. [Merging by Indexes with the `left_index` and `right_index` Parameters](#section9)
# 10. [The `.join()` Method](#section10)
# 11. [The `pd.merge()` Method](#section11)

# %%
import pandas as pd

# %%
week1 = pd.read_csv("../data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("../data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("../data/Restaurant - Customers.csv")
foods = pd.read_csv("../data/Restaurant - Foods.csv")
# Out:
#    Food ID   Food Item  Price
# 0        1       Sushi   3.99
# 1        2     Burrito   9.99
# 2        3        Taco   2.99
# 3        4  Quesadilla   4.25
# 4        5       Pizza   2.49
# 5        6       Pasta  13.99
# 6        7       Steak  24.99
# 7        8       Salad  11.25
# 8        9       Donut   0.99
# 9       10       Drink   1.75

# %% [markdown]
# <a id="section1"></a>
# [Index](#section0)
# ### The `pd.concat()` Method, Part 1

# %%
week1 = pd.read_csv("../data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("../data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("../data/Restaurant - Customers.csv")
foods = pd.read_csv("../data/Restaurant - Foods.csv")

# %%
len(week1)
# Out:
# 250

# %%
len(week2)
# Out:
# 250

# %%
pd.concat([week1, week2], ignore_index = False)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [500 rows x 2 columns]

# %%
pd.concat([week1, week2], ignore_index = True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 495          783       10
# 496          556       10
# 497          547        9
# 498          252        9
# 499          249        6
#
# [500 rows x 2 columns]

# %%
len(pd.concat([week1, week2]))
# Out:
# 500

# %% [markdown]
# <a id="section2"></a>
# [Index](#section0)
# ### The `pd.concat()` Method, Part 2

# %%
week1 = pd.read_csv("../data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("../data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("../data/Restaurant - Customers.csv")
foods = pd.read_csv("../data/Restaurant - Foods.csv")

# %%
########################################
############# muy bueno!! ##############
########################################

sales = pd.concat([week1, week2], keys = ["week 1", "week 2"])

# %%
sales
# Out:
#             Customer ID  Food ID
# week 1 0            537        9
#        1             97        4
#        2            658        1
#        3            202        2
#        4            155        9
# ...                 ...      ...
# week 2 245          783       10
#        246          556       10
#        247          547        9
#        248          252        9
#        249          249        6
#
# [500 rows x 2 columns]

# %%
sales.loc[("week 1",)]
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          413        9
# 246          926        6
# 247          134        3
# 248          396        6
# 249          535       10
#
# [250 rows x 2 columns]

# %%
sales.loc[("week 1", 25)]
# Out:
# Customer ID    329
# Food ID          8
# Name: (week 1, 25), dtype: int64

# %%
########################################
#############  DataFrame  ##############
########################################

pd.DataFrame(sales.loc[("week 1", 25)])
# Out:
#             week 1
#                 25
# Customer ID    329
# Food ID          8

# %%
sales.loc[("week 2", 240), "Customer ID"]
# Out:
# 734

# %%
pd.DataFrame(sales.loc[("week 2", 240), ["Customer ID", "Food ID"]])
# Out:
#             week 2
#                240
# Customer ID    734
# Food ID          1

# %%
# sales.ix[("week 2", 240), "Customer ID"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-0cd2bfd959ee> in <module>
# ----> 1 sales.ix[("week 2", 240), "Customer ID"]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'ix'

# %% [markdown]
# <a id="section3"></a>
# [Index](#section0)
# ### The `.append()` Method

# %%
week1 = pd.read_csv("../data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("../data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("../data/Restaurant - Customers.csv")
foods = pd.read_csv("../data/Restaurant - Foods.csv")

# %%
########################################
############# interesante ##############
########################################

sales = week2.append(week1, ignore_index = True)
sales
# Out:
#      Customer ID  Food ID
# 0            688       10
# 1            813        7
# 2            495       10
# 3            189        5
# 4            267        3
# ..           ...      ...
# 495          413        9
# 496          926        6
# 497          134        3
# 498          396        6
# 499          535       10
#
# [500 rows x 2 columns]

# %% [markdown]
# <a id="section4"></a>
# [Index](#section0)
# ### Inner Joins, Part 1

# %%
week1 = pd.read_csv("../data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("../data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("../data/Restaurant - Customers.csv")
foods = pd.read_csv("../data/Restaurant - Foods.csv")

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
# Food ID_x represents week1
week1.merge(week2, how = "inner", on = "Customer ID")
# Out:
#     Customer ID  Food ID_x  Food ID_y
# 0           537          9          5
# 1           155          9          3
# 2           155          1          3
# 3           503          5          8
# 4           503          5          9
# ..          ...        ...        ...
# 57          945          5          4
# 58          343          3          5
# 59          343          3          2
# 60          343          3          7
# 61          621          9          6
#
# [62 rows x 3 columns]

# %%
week1.merge(week2, how = "inner", on = "Customer ID", suffixes = [" - week 1", " - week 2"])
# Out:
#     Customer ID  Food ID - week 1  Food ID - week 2
# 0           537                 9                 5
# 1           155                 9                 3
# 2           155                 1                 3
# 3           503                 5                 8
# 4           503                 5                 9
# ..          ...               ...               ...
# 57          945                 5                 4
# 58          343                 3                 5
# 59          343                 3                 2
# 60          343                 3                 7
# 61          621                 9                 6
#
# [62 rows x 3 columns]

# %%
week1[week1["Customer ID"] == 155]
# Out:
#     Customer ID  Food ID
# 4           155        9
# 17          155        1

# %%
week2[week2["Customer ID"] == 155]
# Out:
#      Customer ID  Food ID
# 208          155        3

# %% [markdown]
# <a id="section5"></a>
# [Index](#section0)
# ### Inner Joins, Part 2

# %%
week1 = pd.read_csv("../data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("../data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("../data/Restaurant - Customers.csv")
foods = pd.read_csv("../data/Restaurant - Foods.csv")

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
week1.merge(week2, how = "inner", on = ["Customer ID", "Food ID"])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
week1[week1["Customer ID"] == 578]
# Out:
#      Customer ID  Food ID
# 224          578        5

# %%
week2[week2["Customer ID"] == 578]
# Out:
#      Customer ID  Food ID
# 29           578        5
# 189          578        5

# %% [markdown]
# <a id="section6"></a>
# [Index](#section0)
# ### Outer Joins

# %%
week1 = pd.read_csv("../data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("../data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("../data/Restaurant - Customers.csv")
foods = pd.read_csv("../data/Restaurant - Foods.csv")

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
########################################
#### buena funcion la del indicador ####
#######################################


merged = week1.merge(week2, how = "outer", on = "Customer ID", suffixes = [" - Week 1", " - Week 2"],
            indicator = True)
merged
# Out:
#      Customer ID  Food ID - Week 1  Food ID - Week 2      _merge
# 0            537               9.0               5.0        both
# 1             97               4.0               NaN   left_only
# 2            658               1.0               NaN   left_only
# 3            202               2.0               NaN   left_only
# 4            155               9.0               3.0        both
# ..           ...               ...               ...         ...
# 449          855               NaN               4.0  right_only
# 450          559               NaN              10.0  right_only
# 451          276               NaN               4.0  right_only
# 452          556               NaN              10.0  right_only
# 453          252               NaN               9.0  right_only
#
# [454 rows x 4 columns]

# %%
merged["_merge"].value_counts()
# Out:
# right_only    197
# left_only     195
# both           62
# Name: _merge, dtype: int64

# %%
mask = merged["_merge"].isin(["left_only", "right_only"])
merged[mask]
# Out:
#      Customer ID  Food ID - Week 1  Food ID - Week 2      _merge
# 1             97               4.0               NaN   left_only
# 2            658               1.0               NaN   left_only
# 3            202               2.0               NaN   left_only
# 6            213               8.0               NaN   left_only
# 7            600               1.0               NaN   left_only
# ..           ...               ...               ...         ...
# 449          855               NaN               4.0  right_only
# 450          559               NaN              10.0  right_only
# 451          276               NaN               4.0  right_only
# 452          556               NaN              10.0  right_only
# 453          252               NaN               9.0  right_only
#
# [392 rows x 4 columns]

# %% [markdown]
# <a id="section7"></a>
# [Index](#section0)
# ### Left Joins

# %%
week1 = pd.read_csv("../data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("../data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("../data/Restaurant - Customers.csv")
foods = pd.read_csv("../data/Restaurant - Foods.csv")

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
foods.head(3)
# Out:
#    Food ID Food Item  Price
# 0        1     Sushi   3.99
# 1        2   Burrito   9.99
# 2        3      Taco   2.99

# %%
week1 = week1.merge(foods, how = "left", on = "Food ID", sort = True)

# %%
week1.head()
# Out:
#    Customer ID  Food ID Food Item  Price
# 0          658        1     Sushi   3.99
# 1          600        1     Sushi   3.99
# 2          155        1     Sushi   3.99
# 3          341        1     Sushi   3.99
# 4           20        1     Sushi   3.99

# %% [markdown]
# <a id="section8"></a>
# [Index](#section0)
# ### The `left_on` and `right_on` Parameters

# %%
week1 = pd.read_csv("../data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("../data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("../data/Restaurant - Customers.csv")
foods = pd.read_csv("../data/Restaurant - Foods.csv")

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
week2_1 = week2.merge(customers, how = "left", left_on = "Customer ID", right_on = "ID", sort = True)
week2_1
# Out:
#      Customer ID  Food ID   ID First Name Last Name  Gender        Company  \
# 0              8        6    8    Frances     Adams  Female       Dabshots
# 1             13        2   13       Ruth   Alvarez  Female    Twitterlist
# 2             21        4   21     Albert     Burns    Male      Rhynoodle
# 3             24        8   24      Donna    Thomas  Female        Jaxbean
# 4             27        4   27    Jessica   Bennett  Female  Twitternation
# ..           ...      ...  ...        ...       ...     ...            ...
# 245          968        4  968     Teresa  Reynolds  Female       Flashdog
# 246          969        3  969      Marie     Ortiz  Female          Meejo
# 247          977        7  977    Cynthia     Dixon  Female        Skalith
# 248          994        2  994   Clarence    Morgan    Male       Edgewire
# 249          996       10  996      Debra    Garcia  Female   Dazzlesphere
#
#                        Occupation
# 0                   Developer III
# 1     Mechanical Systems Engineer
# 2                Junior Executive
# 3           Chief Design Engineer
# 4               Account Executive
# ..                            ...
# 245  Budget/Accounting Analyst IV
# 246            Research Associate
# 247      Automation Specialist II
# 248                  Geologist II
# 249           Structural Engineer
#
# [250 rows x 8 columns]

# %%
week2 = week2.merge(customers, how = "left", left_on = "Customer ID", right_on = "ID", sort = True).drop("ID", axis = "columns")

# %%
week2.head()
# Out:
#    Customer ID  Food ID First Name Last Name  Gender        Company  \
# 0            8        6    Frances     Adams  Female       Dabshots
# 1           13        2       Ruth   Alvarez  Female    Twitterlist
# 2           21        4     Albert     Burns    Male      Rhynoodle
# 3           24        8      Donna    Thomas  Female        Jaxbean
# 4           27        4    Jessica   Bennett  Female  Twitternation
#
#                     Occupation
# 0                Developer III
# 1  Mechanical Systems Engineer
# 2             Junior Executive
# 3        Chief Design Engineer
# 4            Account Executive

# %% [markdown]
# <a id="section9"></a>
# [Index](#section0)
# ### Merging by Indexes with the `left_index` and `right_index` Parameters

# %%
week1 = pd.read_csv("../data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("../data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("../data/Restaurant - Customers.csv", index_col = "ID")
foods = pd.read_csv("../data/Restaurant - Foods.csv", index_col = "Food ID")

# %%
foods.head(3)
# Out:
#         Food Item  Price
# Food ID
# 1           Sushi   3.99
# 2         Burrito   9.99
# 3            Taco   2.99

# %%
customers.head(3)
# Out:
#    First Name Last Name  Gender  Company                     Occupation
# ID
# 1      Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 2    Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 3       Roger     Black    Male  Tagfeed              Account Executive

# %%
# right_index = True, indica q use el index para el join
sales = week1.merge(customers, how = "left", left_on = "Customer ID", right_index = True)
sales = sales.merge(foods, how = "left", left_on = "Food ID", right_index = True)
sales.head(3)
# Out:
#    Customer ID  Food ID First Name Last Name  Gender    Company  \
# 0          537        9     Cheryl   Carroll  Female   Zoombeat
# 1           97        4     Amanda   Watkins  Female        Ozu
# 2          658        1    Patrick      Webb    Male  Browsebug
#
#                       Occupation   Food Item  Price
# 0               Registered Nurse       Donut   0.99
# 1            Account Coordinator  Quesadilla   4.25
# 2  Community Outreach Specialist       Sushi   3.99

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
week1.merge(week2, how = "left", left_index = True, right_index = True, suffixes = [" - Week 1", " - Week 2"])
# Out:
#      Customer ID - Week 1  Food ID - Week 1  Customer ID - Week 2  \
# 0                     537                 9                   688
# 1                      97                 4                   813
# 2                     658                 1                   495
# 3                     202                 2                   189
# 4                     155                 9                   267
# 5                     213                 8                   310
# 6                     600                 1                   761
# 7                     503                 5                   443
# 8                      71                 3                   729
# 9                     174                 3                   741
# 10                    961                 9                   847
# 11                    966                 5                   156
# 12                    641                 4                   550
# 13                    288                 2                   620
# 14                    149                 4                   272
# 15                    954                 2                   511
# 16                    147                 9                     8
# 17                    155                 1                   534
# 18                    550                 6                   909
# 19                    101                 7                   732
# 20                    549                 6                   372
# 21                     75                 6                   713
# 22                     78                 7                   496
# 23                    514                 5                   381
# 24                    833                 7                    13
# 25                    329                 8                   101
# 26                    586                10                   325
# 27                    341                 1                   674
# 28                    519                10                   564
# 29                    680                 9                   578
# ..                    ...               ...                   ...
# 220                   147                 8                   495
# 221                   745                 4                   794
# 222                   184                 3                   734
# 223                   828                 8                   540
# 224                   578                 5                   735
# 225                   491                 4                   940
# 226                    62                 4                   571
# 227                    77                 9                   888
# 228                   506                 9                   664
# 229                   271                 9                   343
# 230                   584                10                   143
# 231                   148                 5                   505
# 232                   595                 3                    54
# 233                   274                10                   959
# 234                   646                 1                   367
# 235                   520                 8                   883
# 236                   644                 8                   251
# 237                   725                 8                   855
# 238                   934                 4                   233
# 239                   151                10                   559
# 240                   945                 5                   734
# 241                   343                 3                   677
# 242                   380                 9                   276
# 243                   911                 4                    45
# 244                   621                 9                   945
# 245                   413                 9                   783
# 246                   926                 6                   556
# 247                   134                 3                   547
# 248                   396                 6                   252
# 249                   535                10                   249
#
#      Food ID - Week 2
# 0                  10
# 1                   7
# 2                  10
# 3                   5
# 4                   3
# 5                   5
# 6                   2
# 7                   5
# 8                   9
# 9                   8
# 10                  6
# 11                 10
# 12                  7
# 13                 10
# 14                  4
# 15                  2
# 16                  6
# 17                  7
# 18                  6
# 19                  9
# 20                  4
# 21                  1
# 22                  3
# 23                  9
# 24                  2
# 25                  4
# 26                  7
# 27                  2
# 28                  8
# 29                  5
# ..                ...
# 220                 2
# 221                 6
# 222                10
# 223                 3
# 224                 2
# 225                 8
# 226                 7
# 227                 2
# 228                 6
# 229                 7
# 230                 4
# 231                 3
# 232                 8
# 233                 2
# 234                 8
# 235                 8
# 236                 9
# 237                 4
# 238                 3
# 239                10
# 240                 1
# 241                 3
# 242                 4
# 243                 8
# 244                 4
# 245                10
# 246                10
# 247                 9
# 248                 9
# 249                 6
#
# [250 rows x 4 columns]

# %% [markdown]
# <a id="section10"></a>
# [Index](#section0)
# ### The `.join()` Method

# %%
week1 = pd.read_csv("../data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("../data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("../data/Restaurant - Customers.csv")
foods = pd.read_csv("../data/Restaurant - Foods.csv")
satisfaction = pd.read_csv("../data/Restaurant - Week 1 Satisfaction.csv")

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
satisfaction.head(3)
# Out:
#    Satisfaction Rating
# 0                    2
# 1                    7
# 2                    3

# %%
week1.merge(satisfaction, how = "left", left_index = True, right_index = True).head()
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3
# 3          202        2                    7
# 4          155        9                   10

# %%
# this method uses less code
week1.join(satisfaction).head()
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3
# 3          202        2                    7
# 4          155        9                   10

# %% [markdown]
# <a id="section11"></a>
# [Index](#section0)
# ### The `pd.merge()` Method

# %%
week1 = pd.read_csv("../data/Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("../data/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("../data/Restaurant - Customers.csv")
foods = pd.read_csv("../data/Restaurant - Foods.csv")
satisfaction = pd.read_csv("../data/Restaurant - Week 1 Satisfaction.csv")

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
pd.merge(week1, customers, how = "left", left_on = "Customer ID", right_on = "ID")
# Out:
#      Customer ID  Food ID   ID First Name Last Name  Gender    Company  \
# 0            537        9  537     Cheryl   Carroll  Female   Zoombeat
# 1             97        4   97     Amanda   Watkins  Female        Ozu
# 2            658        1  658    Patrick      Webb    Male  Browsebug
# 3            202        2  202      Louis  Campbell    Male  Rhynoodle
# 4            155        9  155    Carolyn      Diaz  Female   Gigazoom
# ..           ...      ...  ...        ...       ...     ...        ...
# 245          413        9  413      Diane    Bailey  Female    Wikibox
# 246          926        6  926       Anne    Wagner  Female      Skyba
# 247          134        3  134      Diana      Hall  Female      Quinu
# 248          396        6  396       Juan    Romero    Male    Zoonder
# 249          535       10  535      Nancy       Cox  Female     Trudeo
#
#                         Occupation
# 0                 Registered Nurse
# 1              Account Coordinator
# 2    Community Outreach Specialist
# 3       Account Representative III
# 4       Database Administrator III
# ..                             ...
# 245               Technical Writer
# 246                Legal Assistant
# 247              Financial Advisor
# 248             Analyst Programmer
# 249             Research Associate
#
# [250 rows x 8 columns]
